# %% [markdown]
# # TODO:
# - Check which crimes are correl. with socio-economic status (proxy: race (and sex and age?))
# - Check whether race/age/sex is correl. with COMPAS scores
# - Check whether race/age/sex is correl. with OUR scores
# - Try out some other models as well (SVMs, Random Forests, Naive Bayes)

# %% [markdown]
# # Trying stuff out
# Import our tools

# %%
import pandas as pd

# %% [markdown]
# Load in the relevant data, parsing the date fields to a format pandas understands on the way.

# %%
df = pd.read_csv(
    'compas-scores.csv',
    usecols=[
        'sex',
        'age',
        #'age_cat',
        'race',
        'juv_fel_count', 
        #'decile_score', 
        'juv_misd_count',
        'juv_other_count', 
        'priors_count', 
        'days_b_screening_arrest',
        'c_jail_in', 
        'c_jail_out',
        'c_offense_date',
        'c_arrest_date', 
        'c_days_from_compas', 
        'c_charge_degree',
        'c_charge_desc', 
        'is_recid', 
        #'num_r_cases', 
        #'r_charge_degree', 
        #'r_days_from_arrest', 
        #'r_offense_date',
        #'r_charge_desc', 
        #'r_jail_in', 
        #'r_jail_out', 
        #'is_violent_recid',
        #'num_vr_cases', 
        #'vr_charge_degree', 
        #'vr_offense_date',
        #'vr_charge_desc', 
        #'v_decile_score',
        #'v_score_text', 
        #'v_screening_date', 
        #'score_text', 
    ],
    parse_dates=[
        'c_jail_in', 
        'c_jail_out', 
        'c_offense_date', 
        'c_arrest_date', 
        #'r_offense_date', 
        #'r_jail_in', 
        #'r_jail_out', 
        #'vr_offense_date',
        #'v_screening_date'
    ]
)

# %%
print(df.shape)
df = df[df['c_days_from_compas'] <= 10]
print(df.shape)
# Out:
# (11757, 16)
# (8938, 16)

# %%
df['c_charge_desc'].value_counts().to_csv('lol.cvs')

# %% [markdown]
# Transform all string data to lowercase and remove extra whitespace. This handles some problematic cases where we have e.g. 'Id theft' and 'ID Theft' as separate labels.

# %%
df = df.applymap(lambda s : s.lower().strip() if type(s) == str else s)
df['c_charge_desc'].value_counts().to_csv('cadasdas.csv')

# %% [markdown]
# Transform all string columns to groups of binary columns. This is probably not the smartest way to go about this, given that we have so many crime labels. The smart thing to do would probably be some type of a crime classification system, e.g. is_violent, is_with_weapon, etc. But that would require a lot of manual work.

# %%
df = pd.get_dummies(df)

# %% [markdown]
# Check if we have any more object columns (should be none)

# %%
df.dtypes.value_counts()
# Out:
# uint8             449
# int64               6
# datetime64[ns]      4
# float64             2
# dtype: int64

# %% [markdown]
# Calculate jail stay lengths

# %%
df['c_days_in_jail'] = (df['c_jail_out'] - df['c_jail_in']).dt.days.fillna(0).astype(int)
#df['r_days_in_jail'] = (df['r_jail_out'] - df['r_jail_in']).dt.days.fillna(0).astype(int)

# %% [markdown]
# Drop date columns

# %%
df.drop([
        'c_jail_in', 
        'c_jail_out', 
        'c_offense_date', 
        'c_arrest_date', 
        #'r_offense_date', 
        #'r_jail_in', 
        #'r_jail_out', 
        #'vr_offense_date',
        #'v_screening_date'
    ],
    axis='columns',
    inplace=True
)

# %% [markdown]
# Check dtypes again, should be no dates remaining

# %%
df.dtypes.value_counts()
# Out:
# uint8      449
# int64        7
# float64      2
# dtype: int64

# %% [markdown]
# Still a few floats, see what that is all about

# %%
df.select_dtypes(include=['float64'])
# Out:
#        days_b_screening_arrest  c_days_from_compas
# 0                         -1.0                 1.0
# 2                         -1.0                 1.0
# 3                         -1.0                 1.0
# 4                          NaN                 1.0
# 6                          0.0                 0.0
# 7                         -1.0                 1.0
# 8                         -1.0                 1.0
# 9                         -1.0                 1.0
# 10                        -1.0                 1.0
# 11                        -1.0                 1.0
# 13                        -1.0                 1.0
# 14                         0.0                 0.0
# 15                         0.0                 0.0
# 16                         0.0                 0.0
# 17                        -1.0                 1.0
# 20                         0.0                 0.0
# 21                        -1.0                 1.0
# 22                        -1.0                 1.0
# 23                        -1.0                 1.0
# 24                        -1.0                 1.0
# 25                        -1.0                 1.0
# 26                         0.0                 0.0
# 27                        -2.0                 2.0
# 28                         0.0                 0.0
# 29                         0.0                 1.0
# 31                        -1.0                 1.0
# 32                        -1.0                 1.0
# 33                        -1.0                 1.0
# 36                        -1.0                 1.0
# 38                        -1.0                 1.0
# ...                        ...                 ...
# 11724                      0.0                 1.0
# 11725                     -1.0                 1.0
# 11726                      0.0                 1.0
# 11727                      0.0                 0.0
# 11728                     -1.0                 1.0
# 11730                     -1.0                 1.0
# 11731                     -1.0                 1.0
# 11732                     -1.0                 1.0
# 11733                     -1.0                 1.0
# 11734                     -1.0                 1.0
# 11735                     -1.0                 1.0
# 11736                     -1.0                 1.0
# 11737                     -1.0                 1.0
# 11738                     -1.0                 1.0
# 11739                     -2.0                 3.0
# 11740                      0.0                 1.0
# 11741                     -1.0                 1.0
# 11742                     -1.0                 1.0
# 11743                      0.0                 0.0
# 11745                      0.0                 0.0
# 11746                      0.0                 1.0
# 11747                      0.0                 0.0
# 11748                     -1.0                 1.0
# 11749                     -1.0                 1.0
# 11750                     -1.0                 1.0
# 11751                     -2.0                 2.0
# 11752                     -1.0                 1.0
# 11753                     -1.0                 1.0
# 11754                      NaN                 1.0
# 11756                     -1.0                 1.0
#
# [8938 rows x 2 columns]

# %% [markdown]
# At least two look like only NaNs, check to be sure

# %%
#print(df['num_vr_cases'].value_counts())
#print(df['num_r_cases'].value_counts())

# %% [markdown]
# Yeah, NaNs only. We can drop those. The others look pretty meaningless as well, so drop those too.

# %%
df.drop([
        #'num_r_cases',
        #'num_vr_cases',
        'days_b_screening_arrest',
        'c_days_from_compas',
        #'r_days_from_arrest'

    ],
    axis='columns',
    inplace=True
)

# %% [markdown]
# Check if we have any more NaNs hanging around

# %%
for col in df:
    count = len(df[col]) - df[col].count()
    if count:
        print(col, count)

# %% [markdown]
# Should be no more NaNs to go, so we can continue to learning.

# %% [markdown]
# Split to target and explanatory variables

# %%
predicted_variable = 'is_recid'
X = df.loc[:, df.columns != predicted_variable]
y = df.loc[:, df.columns == predicted_variable]
print(X.shape, y.shape)
# Out:
# (8938, 455) (8938, 1)

# %% [markdown]
# Split to train and test sets

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# Train a ridge regression model and check the $R^2$ score. Score of 1 is best possible, values can range to $-\inf$. RidgeCV automatically cross validates (leave-one-out) to figure out the best hyperparameter $\alpha$

# %%
from sklearn import linear_model

model = linear_model.LogisticRegression()
model.fit(X_train, y_train.values.ravel())
print(model.score(X_test, y_test))
# Out:
# 0.733780760626

# %% [markdown]
# That's... not horrible. Let's check which features have the greatest effect on the thing.

# %%
coeffs = [(coef, col) for col, coef in zip(X.columns, model.coef_[0])]
coeffs = sorted(coeffs, reverse=True)
for a, b in coeffs: print(a, b)
# Out:
# 1.29233676478 c_charge_desc_felony committing prostitution
# 1.21420375941 c_charge_desc_petit theft
# 1.13329455331 c_charge_desc_poss f/arm delinq
# 1.04835792942 c_charge_desc_poss alprazolam w/int sell/del
# 1.02120651253 c_charge_desc_neglect child / bodily harm
# 0.983438032543 c_charge_desc_corrupt public servant
# 0.940950020878 c_charge_desc_carrying a concealed weapon
# 0.870246068063 c_charge_desc_harm public servant or family
# 0.832521665792 c_charge_desc_aiding escape
# 0.807823947984 c_charge_desc_viol pretrial release dom viol
# 0.799983465416 c_charge_desc_shoot into vehicle
# 0.793784060193 c_charge_desc_attempted burg/convey/unocc
# 0.793165957547 c_charge_desc_possession of carisoprodol
# 0.77534927392 c_charge_desc_solicit purchase cocaine
# 0.75957826002 c_charge_desc_petit theft/ prior conviction
# 0.733270743709 c_charge_desc_fighting/baiting animals
# 0.732961823164 c_charge_desc_viol injunct domestic violence
# 0.721250786906 c_charge_desc_use of anti-shoplifting device
# 0.671019254476 c_charge_desc_att tamper w/physical evidence
# 0.65606348243 c_charge_desc_unauthorized interf w/railroad
# 0.64583876463 c_charge_desc_criminal mischief
# 0.640966954696 c_charge_desc_felony petit theft
# 0.626988336286 c_charge_desc_unlaw use false name/identity
# 0.62452784281 c_charge_desc_false ownership info/pawn item
# 0.62069480623 c_charge_degree_o
# 0.62023957817 c_charge_desc_felony dui - enhanced
# 0.619167190073 c_charge_desc_contradict statement
# 0.615305327216 c_charge_desc_imperson public officer or emplyee
# 0.606244804525 c_charge_desc_sell/man/del pos/w/int heroin
# 0.597392859063 c_charge_desc_sex batt faml/cust vict 12-17y
# 0.58434737133 c_charge_desc_trespass structure w/dang weap
# 0.571028280057 c_charge_desc_poss of firearm by convic felo
# 0.569733697094 c_charge_desc_prostitution/lewd act assignation
# 0.568894915277 c_charge_desc_aide/abet prostitution lewdness
# 0.567776042724 c_charge_desc_refuse to supply dna sample
# 0.559450866044 c_charge_desc_obstruct officer by disguise
# 0.559369992733 c_charge_desc_uttering worthless check +$150
# 0.552648282743 c_charge_desc_retail theft $300 2nd offense
# 0.545853584434 c_charge_desc_defrauding innkeeper
# 0.543755173104 c_charge_desc_poss similitude of drivers lic
# 0.543474136502 c_charge_desc_unlaw lic use/disply of others
# 0.541993637556 c_charge_desc_poss contr subst w/o prescript
# 0.541389628511 c_charge_desc_battery on fire fighter
# 0.535545947949 c_charge_desc_poss pyrrolidinovalerophenone
# 0.532808843509 c_charge_desc_burglary conveyance occupied
# 0.528767571744 c_charge_desc_delivery of heroin
# 0.527318062092 c_charge_desc_possession of oxymorphone
# 0.520437178474 c_charge_desc_defrauding innkeeper $300/more
# 0.518677168185 c_charge_desc_grand theft of a fire extinquisher
# 0.518553667617 c_charge_desc_sound articles over 100
# 0.507002038444 c_charge_desc_tamper with witness/victim/ci
# 0.504096744049 c_charge_desc_misuse of 911 or e911 system
# 0.501847274531 c_charge_desc_pos cannabis for consideration
# 0.501750540072 c_charge_desc_poss of 1,4-butanediol
# 0.49774668614 c_charge_desc_burglary dwelling assault/batt
# 0.495403946621 c_charge_desc_lewdness violation
# 0.492085499173 c_charge_desc_poss counterfeit payment inst
# 0.491051184775 c_charge_desc_poss/sell/del cocaine 1000ft sch
# 0.489050859914 c_charge_desc_trespass property w/dang weap
# 0.487977332316 c_charge_desc_extradition/defendants
# 0.487909142663 c_charge_desc_pos methylenedioxymethcath w/i/d/s
# 0.484854719292 c_charge_desc_felon in pos of firearm or amm
# 0.483763959347 c_charge_desc_poss/sell/del/man amobarbital
# 0.483640804672 c_charge_desc_criminal mischief damage <$200
# 0.482063438417 c_charge_desc_pl/unlaw use credit card
# 0.472936955709 c_charge_desc_poss cntrft contr sub w/intent
# 0.468674339134 c_charge_desc_traffic counterfeit cred cards
# 0.468231001449 c_charge_desc_live on earnings of prostitute
# 0.464598117793 c_charge_desc_solicitation on felony 3 deg
# 0.463171011103 c_charge_desc_deliver cocaine 1000ft church
# 0.461102819124 c_charge_desc_drivg while lic suspd/revk/can
# 0.455439009229 c_charge_desc_deliver cannabis 1000ftsch
# 0.452709945296 c_charge_desc_lewd act presence child 16-
# 0.449051355972 c_charge_desc_disrupting school function
# 0.447522634161 c_charge_desc_ride tri-rail without paying
# 0.444552148419 c_charge_desc_manslaughter w/weapon/firearm
# 0.440981179236 c_charge_desc_tamper with witness
# 0.437367273884 c_charge_desc_bribery athletic contests
# 0.433395675365 c_charge_desc_attempted burg/struct/unocc
# 0.431030306897 c_charge_desc_escape
# 0.429986161521 c_charge_desc_assault law enforcement officer
# 0.426836838878 c_charge_desc_tresspass in structure or conveyance
# 0.426272876052 c_charge_desc_carjacking w/o deadly weapon
# 0.421353657771 c_charge_desc_del cannabis at/near park
# 0.41895761746 c_charge_desc_voyeurism
# 0.416444713799 c_charge_desc_del cannabis for consideration
# 0.415144145845 c_charge_desc_littering
# 0.413090259517 c_charge_desc_trespass on school grounds
# 0.412756292086 c_charge_desc_susp drivers lic 1st offense
# 0.40843294793 c_charge_desc_possession of clonazepam
# 0.406438714375 c_charge_desc_crim attempt/solic/consp
# 0.401827006478 c_charge_desc_poss firearm w/altered id#
# 0.396398504401 c_charge_desc_posses/disply susp/revk/frd dl
# 0.395207572469 c_charge_desc_trans/harm/material to a minor
# 0.39236782726 c_charge_desc_false name by person arrest
# 0.383949028284 c_charge_desc_petit theft $100- $300
# 0.377443608931 c_charge_desc_robbery w/firearm
# 0.369206538252 c_charge_desc_poss tetrahydrocannabinols
# 0.368836121572 c_charge_desc_dealing in stolen property
# 0.367363091496 c_charge_desc_principal in the first degree
# 0.365237648204 c_charge_desc_possession of heroin
# 0.36269884595 c_charge_desc_solic to commit battery
# 0.362371641564 c_charge_desc_fraudulent use of credit card
# 0.358437102157 c_charge_desc_poss of cocaine w/i/d/s 1000ft park
# 0.354706514986 c_charge_desc_attempted deliv control subst
# 0.354074441762 c_charge_desc_felony battery
# 0.353764719263 c_charge_desc_fabricating physical evidence
# 0.352974053003 c_charge_desc_issuing a worthless draft
# 0.349359204153 c_charge_desc_poss 3,4 mdma (ecstasy)
# 0.345606744685 c_charge_desc_possession of methadone
# 0.337617270969 c_charge_desc_poss cocaine/intent to del/sel
# 0.334589841404 c_charge_desc_aggress/panhandle/beg/solict
# 0.330475070781 c_charge_desc_possession of butylone
# 0.325507313299 c_charge_desc_possession of cocaine
# 0.324669881827 c_charge_desc_battery on law enforc officer
# 0.320212689761 c_charge_desc_grand theft in the 1st degree
# 0.317898473034 c_charge_desc_resist/obstruct w/o violence
# 0.314586560305 c_charge_desc_possess countrfeit credit card
# 0.311771760125 c_charge_desc_dui/property damage/persnl inj
# 0.308815239534 c_charge_desc_fail register vehicle
# 0.299215543469 c_charge_desc_shoot in occupied dwell
# 0.295728664793 c_charge_desc_carjacking with a firearm
# 0.295453355147 sex_male
# 0.292367570658 c_charge_desc_crlty twrd child urge oth act
# 0.291823963066 c_charge_desc_possession of morphine
# 0.291233132711 c_charge_desc_criminal mischief>$200<$1000
# 0.290751500165 c_charge_desc_viol injunction protect dom vi
# 0.285897173177 c_charge_desc_poss oxycodone w/int/sell/del
# 0.284759874525 c_charge_desc_throw deadly missile into veh
# 0.274043236091 c_charge_desc_burglary dwelling occupied
# 0.270364462162 c_charge_desc_leaving the scene of accident
# 0.268315208316 race_african-american
# 0.262439416853 c_charge_desc_tresspass struct/conveyance
# 0.248057172483 c_charge_desc_poss of rx without rx
# 0.247281258132 c_charge_desc_assault
# 0.245430097702 c_charge_desc_false motor veh insurance card
# 0.234410679896 c_charge_desc_crimin mischief damage $1000+
# 0.233699036187 c_charge_desc_possession burglary tools
# 0.231771049928 c_charge_desc_agg fleeing and eluding
# 0.227439322967 c_charge_desc_possess cannabis/20 grams or less
# 0.223920482837 c_charge_desc_prowling/loitering
# 0.219392255087 c_charge_desc_prostitution/lewdness/assign
# 0.217437666506 juv_other_count
# 0.204720054528 c_charge_desc_attempt armed burglary dwell
# 0.203046646933 c_charge_desc_disorderly conduct
# 0.202039132228 c_charge_desc_trespass private property
# 0.181976829069 c_charge_desc_sale/del cannabis at/near scho
# 0.180979982998 c_charge_desc_poss pyrrolidinobutiophenone
# 0.17836453993 c_charge_desc_traff in cocaine <400g>150 kil
# 0.175730367924 c_charge_desc_trespass other struct/conve
# 0.174269337526 c_charge_desc_burglary structure assault/batt
# 0.17317217207 c_charge_desc_violation of boater safety id
# 0.172774405698 c_charge_desc_deliver cocaine 1000ft school
# 0.172293627299 c_charge_desc_dwls canceled disqul 1st off
# 0.166205735299 c_charge_desc_tampering with physical evidence
# 0.162514139708 c_charge_desc_lewd or lascivious molestation
# 0.152133888262 c_charge_desc_threat public servant
# 0.1462678233 c_charge_desc_open carrying of weapon
# 0.142917659202 c_charge_desc_grand theft (motor vehicle)
# 0.142452026034 c_charge_desc_att burgl conv occp
# 0.140968345797 c_charge_desc_aggravated assault w/o firearm
# 0.140145731414 c_charge_desc_dui- enhanced
# 0.130189253866 priors_count
# 0.127076673785 c_charge_desc_expired dl more than 6 months
# 0.121419922481 c_charge_desc_burglary structure unoccup
# 0.120115820032 race_caucasian
# 0.11539882473 c_charge_desc_viol prot injunc repeat viol
# 0.109471063172 c_charge_desc_possession of oxycodone
# 0.10914843601 c_charge_desc_exhibition weapon school prop
# 0.106065058335 c_charge_desc_dui - property damage/personal injury
# 0.103493082781 c_charge_desc_grand theft firearm
# 0.0975644606587 c_charge_desc_possession of alcohol under 21
# 0.0897920091488 c_charge_desc_sexual battery / vict 12 yrs +
# 0.0893511844954 c_charge_desc_lve/scen/acc/veh/prop/damage
# 0.0804359237502 c_charge_desc_aggravated battery
# 0.0722311667982 c_charge_desc_burglary conveyance unoccup
# 0.0686484446284 c_charge_desc_burglary dwelling armed
# 0.068227936522 c_charge_desc_giving false crime report
# 0.0665202456534 c_charge_desc_resist officer w/violence
# 0.0647457913617 c_charge_desc_pos cannabis w/intent sel/del
# 0.0530708580955 c_charge_desc_robbery / no weapon
# 0.0495359501005 c_charge_desc_dui blood alcohol above 0.20
# 0.048244333091 c_charge_desc_poss3,4 methylenedioxymethcath
# 0.0451930602259 c_charge_desc_possession of hydromorphone
# 0.0349360571591 c_charge_desc_traffick amphetamine 28g><200g
# 0.0333671142441 race_native american
# 0.0326713599572 c_charge_desc_driving license suspended
# 0.0251632179435 c_charge_desc_agg assault w/int com fel dome
# 0.0215168771529 c_charge_desc_poss of controlled substance
# 0.0197752700743 c_charge_desc_aggrav stalking after injunctn
# 0.017041193009 c_charge_desc_reckless driving
# 0.0148189941042 c_charge_desc_att burgl unoccupied dwel
# 0.0142637341813 c_charge_desc_crim use of personal id info
# 0.0112848042681 c_charge_desc_felony/driving under influence
# 0.0102067202932 c_charge_desc_attempted robbery  no weapon
# 0.00966977257135 c_charge_desc_burglary conveyance armed
# 0.00503041697287 c_charge_desc_agg battery grt/bod/harm
# 0.00169126155594 juv_fel_count
# 0.0 c_charge_desc_unl/disturb education/instui
# 0.0 c_charge_desc_traffick oxycodone     4g><14g
# 0.0 c_charge_desc_solicit prostitutionviolation
# 0.0 c_charge_desc_possession of paraphernalia
# 0.0 c_charge_desc_possess altered bills
# 0.0 c_charge_desc_offer agree secure for lewd act
# 0.0 c_charge_desc_impersonating police officer
# 0.0 c_charge_desc_false info leo during invest
# 0.0 c_charge_desc_dwi w/inj susp lic / habit off
# 0.0 c_charge_desc_deliver oxycodone
# 0.0 c_charge_desc_battery spouse or girlfriend
# 0.0 c_charge_desc_attempted aggravated battery
# 0.0 c_charge_desc_arson in the first degree
# -0.00259737427538 c_days_in_jail
# -0.00769714796409 c_charge_desc_failure to return hired vehicle
# -0.0107961715508 race_other
# -0.0128333681622 c_charge_desc_cash item w/intent to defraud
# -0.0137046716348 c_charge_desc_deliver cannabis
# -0.0153806073203 c_charge_desc_fleeing or eluding a leo
# -0.0192316868975 c_charge_desc_poss unlaw issue id
# -0.0225748273222 c_charge_desc_cruelty toward child
# -0.0273999178258 juv_misd_count
# -0.0332078491856 c_charge_desc_trespass struct/conveyance
# -0.0362909563849 age
# -0.0430141302607 c_charge_desc_felony driving while lic suspd
# -0.0521130212581 c_charge_desc_unlaw lictag/sticker attach
# -0.0530447073323 c_charge_desc_unauth poss id card or dl
# -0.0532560080168 c_charge_desc_sell cocaine
# -0.0633557844686 c_charge_desc_crim/transmit of hiv virus
# -0.0740210549895 c_charge_desc_aggravated battery (firearm)
# -0.0757659269152 c_charge_desc_harass witness/victm/informnt
# -0.0764337627688 c_charge_desc_fail to obey police officer
# -0.0767288158711 c_charge_desc_trespass/property/other structure
# -0.0817496738947 c_charge_desc_att burgl struc/conv dwel/occp
# -0.0860945635237 c_charge_desc_throw missile into pub/priv dw
# -0.0865954155522 c_charge_desc_attempt murder in the first degree
# -0.0876817018431 c_charge_desc_theft of trade secrets
# -0.09262077032 c_charge_desc_aggravated animal cruelty
# -0.0930093796767 c_charge_desc_trespass struct/convey occupy
# -0.10019490074 c_charge_desc_possess drug paraphernalia
# -0.101872314857 race_hispanic
# -0.102104898991 c_charge_desc_felony batt(great bodily harm)
# -0.104012109278 c_charge_desc_consp to traffic methamphetamine
# -0.104352324617 c_charge_desc_armed kidnapping
# -0.105998614271 c_charge_desc_violation license restrictions
# -0.106192761371 c_charge_desc_lewd/lasc battery pers 12+/<16
# -0.109401618257 c_charge_desc_grand theft in the 3rd degree
# -0.109590325551 c_charge_desc_manufacture cannabis
# -0.113020789439 c_charge_desc_driving while license revoked
# -0.114955024515 c_charge_desc_deliver 3,4 methylenediox
# -0.115151277305 c_charge_desc_poss wep conv felon
# -0.116711387099 c_charge_desc_obstruct fire equipment
# -0.120712954586 c_charge_desc_aggravated battery / pregnant
# -0.121895608502 c_charge_desc_threaten throw destruct device
# -0.121975103607 c_charge_desc_leave accd/attend veh/less $50
# -0.123585463561 c_charge_desc_driving while intoxicated
# -0.124106918403 c_charge_desc_attempt sexual batt / vict 12+
# -0.124819792388 c_charge_desc_domestic battery by stran
# -0.130229941438 c_charge_desc_tamper with victim
# -0.131736620569 c_charge_desc_structuring transactions
# -0.137424663456 c_charge_desc_carrying concealed firearm
# -0.137491609367 c_charge_desc_battery on parking enfor speci
# -0.139857207055 c_charge_desc_leaving scene accident w/death
# -0.145160982358 c_charge_desc_fleeing or attmp eluding a leo
# -0.145249070972 c_charge_desc_depriv leo of protect/communic
# -0.14542224487 c_charge_desc_possession of codeine
# -0.145899150144 c_charge_desc_neglect/abuse elderly person
# -0.148613363804 c_charge_desc_felony battery w/prior convict
# -0.149779286417 sex_female
# -0.151237969809 c_charge_desc_opert with susp dl 2nd offens
# -0.152319269751 c_charge_desc_possession of alprazolam
# -0.154321709836 c_charge_desc_delivery of 5-fluoro pb-22
# -0.154613234342 c_charge_desc_operating w/o valid license
# -0.156652816553 c_charge_desc_false 911 call
# -0.157219227375 c_charge_desc_deliver cocaine
# -0.157249861131 c_charge_desc_fail to redeliv hire/leas prop
# -0.158092150999 c_charge_desc_offer agree secure/lewd act
# -0.158297980482 c_charge_desc_reduced/amended to reckless driving
# -0.159725334754 c_charge_desc_fail sex offend report bylaw
# -0.163368621006 c_charge_desc_soliciting for prostitution
# -0.16344697602 c_charge_desc_pos gamma-hydroxybutyric acid
# -0.163455587453 race_asian
# -0.167209276087 c_charge_desc_traveling to meet a minor
# -0.169798390976 c_charge_desc_fail to reg as sexual offender
# -0.171258481748 c_charge_desc_petit theft habitual offender
# -0.172500621236 c_charge_desc_deliver alprazolam
# -0.17975384893 c_charge_desc_uttering a forged instrument
# -0.180195444479 c_charge_desc_procure for prostitution
# -0.181145147147 c_charge_desc_aggravated battery (firearm/actual possession)
# -0.183926014004 c_charge_desc_prostitution
# -0.184641116116 c_charge_desc_consp traff oxycodone  4g><14g
# -0.187798226667 c_charge_desc_throw in occupied dwell
# -0.189107837674 c_charge_desc_possess weapon on school prop
# -0.190469529579 c_charge_desc_aggrav child abuse-agg battery
# -0.195799359456 c_charge_desc_sex offender fail comply w/law
# -0.197426213849 c_charge_desc_obtain property worthless check
# -0.198672006259 c_charge_desc_child abuse
# -0.199038927104 c_charge_desc_hiring with intent to defraud
# -0.199080985662 c_charge_desc_agg battery cause bodily
# -0.199496835492 c_charge_desc_battery on a person over 65
# -0.203401864314 c_charge_desc_aggr child abuse-torture,punish
# -0.20426712178 c_charge_degree_m
# -0.20437268617 c_charge_desc_fail surrender tag/reg/dl
# -0.204489736048 c_charge_desc_simulation of legal process
# -0.206126886174 c_charge_desc_interfere w/traf cont dev rr
# -0.206668926481 c_charge_desc_solicit to deliver cocaine
# -0.209568010003 c_charge_desc_intoxicated/safety of another
# -0.210561111978 c_charge_desc_grand theft on 65 yr or older
# -0.210624505613 c_charge_desc_poss anti-shoplifting device
# -0.210840949826 c_charge_desc_disorderly intoxication
# -0.211173473854 c_charge_desc_burglary unoccupied dwelling
# -0.213259000083 c_charge_desc_poss of ethylone w/i/d/s
# -0.214975827691 c_charge_desc_abuse without great harm
# -0.21552966519 c_charge_desc_obscenity
# -0.215843894158 c_charge_desc_obstruct officer w/violence
# -0.218141620684 c_charge_desc_strong armed  robbery
# -0.218924621485 c_charge_desc_del of jwh-250 2-methox 1-pentyl
# -0.219823093567 c_charge_desc_aggravated manslaughter child
# -0.224549626911 c_charge_desc_possession of ethylone
# -0.22473169578 c_charge_desc_lewd/lasciv molest elder persn
# -0.22481342904 c_charge_desc_possession of anabolic steroid
# -0.22663062527 c_charge_desc_s/m/d/p/w/i sch 1a,1b,1d,2a,2b
# -0.227355265882 c_charge_desc_robbery / weapon
# -0.227413274816 c_charge_desc_burglary damage property>$1000
# -0.231108475128 c_charge_desc_agg abuse elderlly/disabled adult
# -0.238888105718 c_charge_desc_burglary structure occupied
# -0.244965204603 c_charge_desc_video voyeur-<24y on child >16
# -0.244988083538 c_charge_desc_poss pyrrolidinovalerophenone w/i/d/s
# -0.24711845436 c_charge_desc_pos cannabis w/i/d/s near worsh
# -0.247740110449 c_charge_desc_unlawful conveyance of fuel
# -0.249133354608 c_charge_desc_contribute delinquency of a minor
# -0.250697740151 c_charge_desc_att robbery sudd snatch no weap
# -0.258532188083 c_charge_desc_felony dui (level 3)
# -0.263177669754 c_charge_desc_failure to pay taxi cab charge
# -0.264589779056 c_charge_desc_sex battery deft 18+/vict 11-
# -0.265591261921 c_charge_desc_battery emergency care provide
# -0.265886015698 c_charge_desc_burglary conveyance assault/bat
# -0.267223689093 c_charge_desc_burgl dwel/struct/convey armed
# -0.267751133141 c_charge_desc_counterfeit lic plates/sticker
# -0.268177998966 c_charge_desc_interfere with k9/horses duties
# -0.269894637689 c_charge_desc_lewd or lascivious exhibition
# -0.270753615717 c_charge_degree_f
# -0.271374250706 c_charge_desc_deliver cannabis 1000ftchur
# -0.2732847332 c_charge_desc_traffick hydrocodone   4g><14g
# -0.27610396034 c_charge_desc_battery
# -0.279577460895 c_charge_desc_computer pornography
# -0.28108769961 c_charge_desc_false imprisonment
# -0.282488409261 c_charge_desc_unlicensed telemarketing
# -0.283864350414 c_charge_desc_robbery w/deadly weapon
# -0.285236427479 c_charge_desc_discharge firearm in public/res
# -0.28530413947 c_charge_desc_driving under the influence
# -0.285310339448 c_charge_desc_sale/del counterfeit cont subs
# -0.285646142607 c_charge_desc_deposit item w/i/defraud
# -0.285980136568 c_charge_desc_poss drugs w/o a prescription
# -0.28642027053 c_charge_desc_aggravated assault w/dead weap
# -0.289891237201 c_charge_desc_sexual performance by a child
# -0.290991377216 c_charge_desc_falsely impersonating officer
# -0.291888251709 c_charge_desc_delivery of trenbolon acetat
# -0.295107234368 c_charge_desc_possession of xlr11
# -0.295558500949 c_charge_desc_create/poss/use fictitious personal id info
# -0.29612095772 c_charge_desc_aggrav battery w/deadly weapon
# -0.296602197681 c_charge_desc_possession of methamphetamine
# -0.297603183293 c_charge_desc_obtain control substance by fraud
# -0.29875743079 c_charge_desc_uttering forged credit card
# -0.29875743079 c_charge_desc_consp traff oxycodone 28g><30k
# -0.299250240572 c_charge_desc_use of 2 way device to fac fel
# -0.300002456062 c_charge_desc_possession of lsd
# -0.30261343742 c_charge_desc_manage busn w/o city occup lic
# -0.30418319503 c_charge_desc_arrest case no charge
# -0.305160461962 c_charge_desc_sel/pur/mfr/del control substa
# -0.305632206577 c_charge_desc_possession of diazepam
# -0.307719727907 c_charge_desc_arson ii (vehicle)
# -0.310992987884 c_charge_desc_possession of buprenorphine
# -0.312181019608 c_charge_desc_robbery sudd snatch no weapon
# -0.316797156187 c_charge_desc_deliver cocaine 1000ft store
# -0.316804344954 c_charge_desc_grand theft dwell property
# -0.319900530578 c_charge_desc_impair/impede phone/power dwell
# -0.321226399908 c_charge_desc_neglect child / no bodily harm
# -0.325908514902 c_charge_desc_delivery of drug paraphernalia
# -0.326239182366 c_charge_desc_tampering with a victim
# -0.326750423327 c_charge_desc_poss of firearm/ammun/dom viol
# -0.330738888598 c_charge_desc_purchase/p/w/int cannabis
# -0.331957535483 c_charge_desc_conspiracy dealing stolen prop
# -0.333729129711 c_charge_desc_burglary assault/battery armed
# -0.33691506439 c_charge_desc_possession firearm school prop
# -0.337392694212 c_charge_desc_unlaw pos of prson id of another
# -0.337870585011 c_charge_desc_batt/on a specified employee
# -0.344097429128 c_charge_desc_att burgl occp dwelling
# -0.344578885448 c_charge_desc_poss 3,4 methylendioxpyrovlerone
# -0.345700305853 c_charge_desc_lease for purpose trafficking
# -0.347436940345 c_charge_desc_agg fleeing/eluding high speed
# -0.349538477177 c_charge_desc_possess mot veh w/alt vin #
# -0.349721288445 c_charge_desc_doc/cause public danger
# -0.351979812882 c_charge_desc_grand theft unlawful use cc
# -0.352465239176 c_charge_desc_criminal attempt 3rd deg felon
# -0.352546498013 c_charge_desc_poss unlaw issue driver licenc
# -0.359646241872 c_charge_desc_possess/use weapon 1 deg felon
# -0.36916218475 c_charge_desc_burglary structure armed
# -0.374733711343 c_charge_desc_sell cannabis 1000ftchur
# -0.375809619645 c_charge_desc_solicit deliver cocaine
# -0.378472643921 c_charge_desc_criminal attempt 2nd deg felon
# -0.37873172902 c_charge_desc_use scanning device to defraud
# -0.379336899554 c_charge_desc_possession of hydrocodone
# -0.382086923225 c_charge_desc_attempt/solicitation/conspiracy
# -0.383980536489 c_charge_desc_fraud obtain food or lodging
# -0.385003698813 c_charge_desc_trespassing/construction site
# -0.385714879534 c_charge_desc_leave acc/attend veh/more $50
# -0.389267231406 c_charge_desc_sale/del cocaine child care fac
# -0.399206409887 c_charge_desc_possession of fentanyl
# -0.412144360425 c_charge_desc_crim attempt/solicit/consp
# -0.418588134903 c_charge_desc_felony battery (dom strang)
# -0.42744069658 c_charge_desc_offn against intellectual prop
# -0.428437451723 c_charge_desc_exposes culpable negligence
# -0.435857129713 c_charge_desc_organized fraud
# -0.44983917582 c_charge_desc_unauthor copy of sound article
# -0.450932450694 c_charge_desc_possession of phentermine
# -0.452631489926 c_charge_desc_possess w/i/utter forged bills
# -0.454148193034 c_charge_desc_grand theft of the 2nd degree
# -0.458661962542 c_charge_desc_poss/sel/del cocaine 1000ft chur
# -0.462216341287 c_charge_desc_murder 2nd degree w/deadly wep
# -0.471163340479 c_charge_desc_possession child pornography
# -0.478910325775 c_charge_desc_possess cannabis 1000ftsch
# -0.48466456901 c_charge_desc_forge counterfeit credit card
# -0.492933895582 c_charge_desc_culpable negligence
# -0.496760164896 c_charge_desc_d.u.i. serious bodily injury
# -0.504914460759 c_charge_desc_use computer for child exploit
# -0.506178002144 c_charge_desc_stalking (aggravated)
# -0.518691701002 c_charge_desc_del 3,4 methylenedioxymethcath
# -0.525594403951 c_charge_desc_possession of cannabis
# -0.53322419184 c_charge_desc_unauth c/p/s sounds>1000/audio
# -0.540445398326 c_charge_desc_false bomb report
# -0.547630961817 c_charge_desc_kidnapping / domestic violence
# -0.566968523857 c_charge_desc_aggravated battery on 65/older
# -0.573779584947 c_charge_desc_possession of 3,4methylenediox
# -0.600706445489 c_charge_desc_forging bank bills/promis note
# -0.611976271757 c_charge_desc_possession of benzylpiperazine
# -0.617586575166 c_charge_desc_resisting w/o violence
# -0.683270445495 c_charge_desc_retail theft $300 1st offense
# -0.695480358304 c_charge_desc_refuse submit blood/breath test
# -0.696061714462 c_charge_desc_stalking
# -0.699088745294 c_charge_desc_deliver cocaine 1000ft park
# -0.721287524039 c_charge_desc_poss meth/diox/meth/amp (mdma)
# -0.750389357718 c_charge_desc_aggravated assault w/firearm
# -0.800434221611 c_charge_desc_introduce contraband into jail
# -0.812458007586 c_charge_desc_aggrav child abuse-causes harm
# -0.828167715444 c_charge_desc_leaving acc/unattended veh
# -0.829237787515 c_charge_desc_sell or offer for sale counterfeit goods
# -0.841099621711 c_charge_desc_poss of methylethcathinone
# -0.864505106264 c_charge_desc_burglary with assault/battery
# -0.878126074978 c_charge_desc_dui level 0.15 or minor in veh
# -0.910040371917 c_charge_desc_fel drive license perm revoke
# -1.01741834891 c_charge_desc_possession of amphetamine
# -1.0683455532 c_charge_desc_aggravated assault
# -1.10181720261 c_charge_desc_uttering forged bills
# -1.17353885605 c_charge_desc_dui property damage/injury
# -1.18181760977 c_charge_desc_purchase cannabis
# -1.62539093718 c_charge_desc_dui - enhanced

# %%
coeffs = [(coef, col) for col, coef in zip(X.columns, model.coef_[0])]
coeffs = sorted(coeffs, reverse=True)

for a, b in coeffs[:20]: print(a, b)
    
print('...')

orig = {col:coef for coef, col in coeffs}
abss = sorted([(abs(coef), col) for coef, col in coeffs])
near_zero = sorted([(orig[col], col) for coef, col in abss[:50]], reverse=True)
for a, b in near_zero: print(a, b)


print('...')

for a, b in coeffs[-20:]: print(a, b)
# Out:
# 1.29233676478 c_charge_desc_felony committing prostitution
# 1.21420375941 c_charge_desc_petit theft
# 1.13329455331 c_charge_desc_poss f/arm delinq
# 1.04835792942 c_charge_desc_poss alprazolam w/int sell/del
# 1.02120651253 c_charge_desc_neglect child / bodily harm
# 0.983438032543 c_charge_desc_corrupt public servant
# 0.940950020878 c_charge_desc_carrying a concealed weapon
# 0.870246068063 c_charge_desc_harm public servant or family
# 0.832521665792 c_charge_desc_aiding escape
# 0.807823947984 c_charge_desc_viol pretrial release dom viol
# 0.799983465416 c_charge_desc_shoot into vehicle
# 0.793784060193 c_charge_desc_attempted burg/convey/unocc
# 0.793165957547 c_charge_desc_possession of carisoprodol
# 0.77534927392 c_charge_desc_solicit purchase cocaine
# 0.75957826002 c_charge_desc_petit theft/ prior conviction
# 0.733270743709 c_charge_desc_fighting/baiting animals
# 0.732961823164 c_charge_desc_viol injunct domestic violence
# 0.721250786906 c_charge_desc_use of anti-shoplifting device
# 0.671019254476 c_charge_desc_att tamper w/physical evidence
# 0.65606348243 c_charge_desc_unauthorized interf w/railroad
# ...
# 0.068227936522 c_charge_desc_giving false crime report
# 0.0665202456534 c_charge_desc_resist officer w/violence
# 0.0647457913617 c_charge_desc_pos cannabis w/intent sel/del
# 0.0530708580955 c_charge_desc_robbery / no weapon
# 0.0495359501005 c_charge_desc_dui blood alcohol above 0.20
# 0.048244333091 c_charge_desc_poss3,4 methylenedioxymethcath
# 0.0451930602259 c_charge_desc_possession of hydromorphone
# 0.0349360571591 c_charge_desc_traffick amphetamine 28g><200g
# 0.0333671142441 race_native american
# 0.0326713599572 c_charge_desc_driving license suspended
# 0.0251632179435 c_charge_desc_agg assault w/int com fel dome
# 0.0215168771529 c_charge_desc_poss of controlled substance
# 0.0197752700743 c_charge_desc_aggrav stalking after injunctn
# 0.017041193009 c_charge_desc_reckless driving
# 0.0148189941042 c_charge_desc_att burgl unoccupied dwel
# 0.0142637341813 c_charge_desc_crim use of personal id info
# 0.0112848042681 c_charge_desc_felony/driving under influence
# 0.0102067202932 c_charge_desc_attempted robbery  no weapon
# 0.00966977257135 c_charge_desc_burglary conveyance armed
# 0.00503041697287 c_charge_desc_agg battery grt/bod/harm
# 0.00169126155594 juv_fel_count
# 0.0 c_charge_desc_unl/disturb education/instui
# 0.0 c_charge_desc_traffick oxycodone     4g><14g
# 0.0 c_charge_desc_solicit prostitutionviolation
# 0.0 c_charge_desc_possession of paraphernalia
# 0.0 c_charge_desc_possess altered bills
# 0.0 c_charge_desc_offer agree secure for lewd act
# 0.0 c_charge_desc_impersonating police officer
# 0.0 c_charge_desc_false info leo during invest
# 0.0 c_charge_desc_dwi w/inj susp lic / habit off
# 0.0 c_charge_desc_deliver oxycodone
# 0.0 c_charge_desc_battery spouse or girlfriend
# 0.0 c_charge_desc_attempted aggravated battery
# 0.0 c_charge_desc_arson in the first degree
# -0.00259737427538 c_days_in_jail
# -0.00769714796409 c_charge_desc_failure to return hired vehicle
# -0.0107961715508 race_other
# -0.0128333681622 c_charge_desc_cash item w/intent to defraud
# -0.0137046716348 c_charge_desc_deliver cannabis
# -0.0153806073203 c_charge_desc_fleeing or eluding a leo
# -0.0192316868975 c_charge_desc_poss unlaw issue id
# -0.0225748273222 c_charge_desc_cruelty toward child
# -0.0273999178258 juv_misd_count
# -0.0332078491856 c_charge_desc_trespass struct/conveyance
# -0.0362909563849 age
# -0.0430141302607 c_charge_desc_felony driving while lic suspd
# -0.0521130212581 c_charge_desc_unlaw lictag/sticker attach
# -0.0530447073323 c_charge_desc_unauth poss id card or dl
# -0.0532560080168 c_charge_desc_sell cocaine
# -0.0633557844686 c_charge_desc_crim/transmit of hiv virus
# ...
# -0.683270445495 c_charge_desc_retail theft $300 1st offense
# -0.695480358304 c_charge_desc_refuse submit blood/breath test
# -0.696061714462 c_charge_desc_stalking
# -0.699088745294 c_charge_desc_deliver cocaine 1000ft park
# -0.721287524039 c_charge_desc_poss meth/diox/meth/amp (mdma)
# -0.750389357718 c_charge_desc_aggravated assault w/firearm
# -0.800434221611 c_charge_desc_introduce contraband into jail
# -0.812458007586 c_charge_desc_aggrav child abuse-causes harm
# -0.828167715444 c_charge_desc_leaving acc/unattended veh
# -0.829237787515 c_charge_desc_sell or offer for sale counterfeit goods
# -0.841099621711 c_charge_desc_poss of methylethcathinone
# -0.864505106264 c_charge_desc_burglary with assault/battery
# -0.878126074978 c_charge_desc_dui level 0.15 or minor in veh
# -0.910040371917 c_charge_desc_fel drive license perm revoke
# -1.01741834891 c_charge_desc_possession of amphetamine
# -1.0683455532 c_charge_desc_aggravated assault
# -1.10181720261 c_charge_desc_uttering forged bills
# -1.17353885605 c_charge_desc_dui property damage/injury
# -1.18181760977 c_charge_desc_purchase cannabis
# -1.62539093718 c_charge_desc_dui - enhanced

# %% [markdown]
# Let's check the non-crime label ones specifically

# %%
for a, b in coeffs: print(a, b) if 'charge_desc' not in b else ...
# Out:
# 0.0798295169387 c_charge_degree_o
# 0.0501782325222 juv_other_count
# 0.0488913367833 race_african-american
# 0.0414765488602 sex_male
# 0.0263776120591 priors_count
# 0.0157476772352 race_caucasian
# 0.00309473681351 juv_fel_count
# -0.000468122783317 c_days_in_jail
# -0.00320791348621 race_native american
# -0.00559965551894 juv_misd_count
# -0.00642519604519 age
# -0.00745456376594 race_other
# -0.0229589024523 race_hispanic
# -0.0307111532929 c_charge_degree_m
# -0.0310176343141 race_asian
# -0.0414765488602 sex_female
# -0.0491183636458 c_charge_degree_f

# %% [markdown]
# Try linear support vector regression next

# %%
from sklearn import svm

#model = svm.LinearSVR(epsilon=0.5)
#scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=10, n_jobs=2)
#scores

# %% [markdown]
# Marginally better, still pretty bad. Let's try support vector regression with an RBF. In principle it has an infinite-dimensional faeture space so that should get to something reasonable at the cost of possibly overfitting.

# %%
from sklearn import svm

#model = svm.SVR(epsilon=0.5)
#scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=10, n_jobs=3)
#scores

# %% [markdown]
# It's... not bad(?) considering we are using $\frac{1}{3}$ of the data for testing on each round of the cross validation. The resulting $R^2$ values indicate $R \approx 0.6$ which is by no means an abysmal degree of correlation. At the same time, we would expect a significantly higher degree of success based on what the task actually **is**.
#
# Might be problem with the nature of the data, more specifically not enough data for practical learning considering the size of the (unmodified) feature space. We only have ~10x data points to the number of features.
#
# Might want to try, say, a random forest or alternatively doing some tricks with sample generation. Might also be issues regarding colinearity, but that's a bit beyond me, to be quite hones.
