# %% [markdown]
# Import our tools

# %%
import pandas as pd

# %% [markdown]
# Load in the relevant data, parsing the date fields to a format pandas understands on the way.

# %%
df = pd.read_csv(
    'compas-scores.csv',
    usecols=[
        'sex',
        'age',
        #'age_cat',
        'race',
        'juv_fel_count', 
        'decile_score', 
        'juv_misd_count',
        'juv_other_count', 
        'priors_count', 
        'days_b_screening_arrest',
        'c_jail_in', 
        'c_jail_out',
        'c_offense_date',
        'c_arrest_date', 
        'c_days_from_compas', 
        'c_charge_degree',
        'c_charge_desc', 
        'is_recid', 
        'num_r_cases', 
        'r_charge_degree', 
        'r_days_from_arrest', 
        'r_offense_date',
        'r_charge_desc', 
        'r_jail_in', 
        'r_jail_out', 
        'is_violent_recid',
        'num_vr_cases', 
        'vr_charge_degree', 
        'vr_offense_date',
        'vr_charge_desc', 
        #'v_decile_score',
        #'v_score_text', 
        'v_screening_date', 
        #'score_text', 
    ],
    parse_dates=[
        'c_jail_in', 
        'c_jail_out', 
        'c_offense_date', 
        'c_arrest_date', 
        'r_offense_date', 
        'r_jail_in', 
        'r_jail_out', 
        'vr_offense_date',
        'v_screening_date'
    ]
)

# %%
print(df.shape)
df = df[df['c_days_from_compas'] <= 10]
print(df.shape)
# Out:
# (11757, 30)
# (8938, 30)

# %% [markdown]
# Transform all string data to lowercase and remove extra whitespace. This handles some problematic cases where we have e.g. 'Id theft' and 'ID Theft' as separate labels.

# %%
df = df.applymap(lambda s : s.lower().strip() if type(s) == str else s)

# %% [markdown]
# Transform all string columns to groups of binary columns. This is probably not the smartest way to go about this, given that we have so many crime labels. The smart thing to do would probably be some type of a crime classification system, e.g. is_violent, is_with_weapon, etc. But that would require a lot of manual work.

# %%
df = pd.get_dummies(df)

# %% [markdown]
# Check if we have any more object columns (should be none)

# %%
df.dtypes.value_counts()
# Out:
# uint8             865
# datetime64[ns]      9
# int64               8
# float64             5
# dtype: int64

# %% [markdown]
# Calculate jail stay lengths

# %%
df['c_days_in_jail'] = (df['c_jail_out'] - df['c_jail_in']).dt.days.fillna(0).astype(int)
df['r_days_in_jail'] = (df['r_jail_out'] - df['r_jail_in']).dt.days.fillna(0).astype(int)

# %% [markdown]
# Drop date columns

# %%
df.drop([
        'c_jail_in', 
        'c_jail_out', 
        'c_offense_date', 
        'c_arrest_date', 
        'r_offense_date', 
        'r_jail_in', 
        'r_jail_out', 
        'vr_offense_date',
        'v_screening_date'
    ],
    axis='columns',
    inplace=True
)

# %% [markdown]
# Check dtypes again, should be no dates remaining

# %%
df.dtypes.value_counts()
# Out:
# uint8      865
# int64       10
# float64      5
# dtype: int64

# %% [markdown]
# Still a few floats, see what that is all about

# %%
df.select_dtypes(include=['float64'])
# Out:
#        days_b_screening_arrest  c_days_from_compas  num_r_cases  \
# 0                         -1.0                 1.0          NaN
# 2                         -1.0                 1.0          NaN
# 3                         -1.0                 1.0          NaN
# 4                          NaN                 1.0          NaN
# 6                          0.0                 0.0          NaN
# 7                         -1.0                 1.0          NaN
# 8                         -1.0                 1.0          NaN
# 9                         -1.0                 1.0          NaN
# 10                        -1.0                 1.0          NaN
# 11                        -1.0                 1.0          NaN
# 13                        -1.0                 1.0          NaN
# 14                         0.0                 0.0          NaN
# 15                         0.0                 0.0          NaN
# 16                         0.0                 0.0          NaN
# 17                        -1.0                 1.0          NaN
# 20                         0.0                 0.0          NaN
# 21                        -1.0                 1.0          NaN
# 22                        -1.0                 1.0          NaN
# 23                        -1.0                 1.0          NaN
# 24                        -1.0                 1.0          NaN
# 25                        -1.0                 1.0          NaN
# 26                         0.0                 0.0          NaN
# 27                        -2.0                 2.0          NaN
# 28                         0.0                 0.0          NaN
# 29                         0.0                 1.0          NaN
# 31                        -1.0                 1.0          NaN
# 32                        -1.0                 1.0          NaN
# 33                        -1.0                 1.0          NaN
# 36                        -1.0                 1.0          NaN
# 38                        -1.0                 1.0          NaN
# ...                        ...                 ...          ...
# 11724                      0.0                 1.0          NaN
# 11725                     -1.0                 1.0          NaN
# 11726                      0.0                 1.0          NaN
# 11727                      0.0                 0.0          NaN
# 11728                     -1.0                 1.0          NaN
# 11730                     -1.0                 1.0          NaN
# 11731                     -1.0                 1.0          NaN
# 11732                     -1.0                 1.0          NaN
# 11733                     -1.0                 1.0          NaN
# 11734                     -1.0                 1.0          NaN
# 11735                     -1.0                 1.0          NaN
# 11736                     -1.0                 1.0          NaN
# 11737                     -1.0                 1.0          NaN
# 11738                     -1.0                 1.0          NaN
# 11739                     -2.0                 3.0          NaN
# 11740                      0.0                 1.0          NaN
# 11741                     -1.0                 1.0          NaN
# 11742                     -1.0                 1.0          NaN
# 11743                      0.0                 0.0          NaN
# 11745                      0.0                 0.0          NaN
# 11746                      0.0                 1.0          NaN
# 11747                      0.0                 0.0          NaN
# 11748                     -1.0                 1.0          NaN
# 11749                     -1.0                 1.0          NaN
# 11750                     -1.0                 1.0          NaN
# 11751                     -2.0                 2.0          NaN
# 11752                     -1.0                 1.0          NaN
# 11753                     -1.0                 1.0          NaN
# 11754                      NaN                 1.0          NaN
# 11756                     -1.0                 1.0          NaN
#
#        r_days_from_arrest  num_vr_cases
# 0                     NaN           NaN
# 2                     NaN           NaN
# 3                     0.0           NaN
# 4                     NaN           NaN
# 6                     NaN           NaN
# 7                     0.0           NaN
# 8                     NaN           NaN
# 9                     NaN           NaN
# 10                    NaN           NaN
# 11                    NaN           NaN
# 13                    NaN           NaN
# 14                    NaN           NaN
# 15                    NaN           NaN
# 16                    NaN           NaN
# 17                    NaN           NaN
# 20                    NaN           NaN
# 21                    NaN           NaN
# 22                    NaN           NaN
# 23                    1.0           NaN
# 24                    0.0           NaN
# 25                    0.0           NaN
# 26                    NaN           NaN
# 27                    NaN           NaN
# 28                    NaN           NaN
# 29                    NaN           NaN
# 31                    NaN           NaN
# 32                    NaN           NaN
# 33                    NaN           NaN
# 36                    NaN           NaN
# 38                    0.0           NaN
# ...                   ...           ...
# 11724                 NaN           NaN
# 11725                 NaN           NaN
# 11726                 NaN           NaN
# 11727                 NaN           NaN
# 11728                 NaN           NaN
# 11730                 NaN           NaN
# 11731                 NaN           NaN
# 11732                 NaN           NaN
# 11733                 0.0           NaN
# 11734                 NaN           NaN
# 11735                 NaN           NaN
# 11736               149.0           NaN
# 11737                 0.0           NaN
# 11738                 NaN           NaN
# 11739                 NaN           NaN
# 11740                 NaN           NaN
# 11741                 NaN           NaN
# 11742                 NaN           NaN
# 11743                 0.0           NaN
# 11745                 NaN           NaN
# 11746                 NaN           NaN
# 11747                 NaN           NaN
# 11748                 NaN           NaN
# 11749                 NaN           NaN
# 11750                 NaN           NaN
# 11751                 1.0           NaN
# 11752                 NaN           NaN
# 11753                 NaN           NaN
# 11754                 NaN           NaN
# 11756                 NaN           NaN
#
# [8938 rows x 5 columns]

# %% [markdown]
# At least two look like only NaNs, check to be sure

# %%
print(df['num_vr_cases'].value_counts())
print(df['num_r_cases'].value_counts())
# Out:
# Series([], Name: num_vr_cases, dtype: int64)
# Series([], Name: num_r_cases, dtype: int64)

# %% [markdown]
# Yeah, NaNs only. We can drop those. The others look pretty meaningless as well, so drop those too.

# %%
df.drop([
        'num_r_cases',
        'num_vr_cases',
        'days_b_screening_arrest',
        'c_days_from_compas',
        'r_days_from_arrest'

    ],
    axis='columns',
    inplace=True
)

# %% [markdown]
# Check if we have any more NaNs hanging around

# %%
for col in df:
    count = len(df[col]) - df[col].count()
    if count:
        print(col, count)

# %% [markdown]
# Should be no more NaNs to go, so we can continue to learning.

# %% [markdown]
# Split to target and explanatory variables

# %%
predicted_variable = 'decile_score'
X = df.loc[:, df.columns != predicted_variable]
y = df.loc[:, df.columns == predicted_variable]
print(X.shape, y.shape)
# Out:
# (8938, 874) (8938, 1)

# %% [markdown]
# Split to train and test sets

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# Train a ridge regression model and check the $R^2$ score. Score of 1 is best possible, values can range to $-\inf$. RidgeCV automatically cross validates (leave-one-out) to figure out the best hyperparameter $\alpha$

# %%
from sklearn import linear_model

model = linear_model.RidgeCV(scoring='explained_variance')
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
print('lol')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/venv/lib/python3.5/site-packages/sklearn/metrics/scorer.py in get_scorer(scoring)
#     204         try:
# --> 205             scorer = SCORERS[scoring]
#     206         except KeyError:
#
# KeyError: 'explained_variance'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ca70fc57a405> in <module>()
#       2
#       3 model = linear_model.RidgeCV(scoring='explained_variance')
# ----> 4 model.fit(X_train, y_train)
#       5 print(model.score(X_test, y_test))
#       6 print('lol')
#
# ~/venv/lib/python3.5/site-packages/sklearn/linear_model/ridge.py in fit(self, X, y, sample_weight)
#    1080                                   gcv_mode=self.gcv_mode,
#    1081                                   store_cv_values=self.store_cv_values)
# -> 1082             estimator.fit(X, y, sample_weight=sample_weight)
#    1083             self.alpha_ = estimator.alpha_
#    1084             if self.store_cv_values:
#
# ~/venv/lib/python3.5/site-packages/sklearn/linear_model/ridge.py in fit(self, X, y, sample_weight)
#    1000         C = []
#    1001
# -> 1002         scorer = check_scoring(self, scoring=self.scoring, allow_none=True)
#    1003         error = scorer is None
#    1004
#
# ~/venv/lib/python3.5/site-packages/sklearn/metrics/scorer.py in check_scoring(estimator, scoring, allow_none)
#     250                         "'fit' method, %r was passed" % estimator)
#     251     if isinstance(scoring, six.string_types):
# --> 252         return get_scorer(scoring)
#     253     elif has_scoring:
#     254         # Heuristic to ensure user has not passed a metric
#
# ~/venv/lib/python3.5/site-packages/sklearn/metrics/scorer.py in get_scorer(scoring)
#     209             raise ValueError('%r is not a valid scoring value. '
#     210                              'Valid options are %s'
# --> 211                              % (scoring, sorted(scorers)))
#     212     else:
#     213         scorer = scoring
#
# ValueError: 'explained_variance' is not a valid scoring value. Valid options are ['accuracy', 'adjusted_rand_score', 'average_precision', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'neg_log_loss', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'roc_auc']

# %% [markdown]
# That's... not horrible. Let's check which features have the greatest effect on the thing.

# %%
coeffs = [(coef, col) for col, coef in zip(X.columns, model.coef_[0])]
coeffs = sorted(coeffs, reverse=True)

for a, b in coeffs[:20]: print(a, b)
    
print('...')

orig = {col:coef for coef, col in coeffs}
abss = sorted([(abs(coef), col) for coef, col in coeffs])
near_zero = sorted([(orig[col], col) for coef, col in abss[:50]], reverse=True)
for a, b in near_zero: print(a, b)


print('...')

for a, b in coeffs[-20:]: print(a, b)
# Out:
# 1.39733712844 c_charge_desc_felony petit theft
# 1.33286223897 c_charge_desc_deliver 3,4 methylenediox
# 1.00966859115 c_charge_desc_tampering with physical evidence
# 0.871561651017 c_charge_desc_disorderly intoxication
# 0.864869177347 c_charge_desc_grand theft dwell property
# 0.849941928109 c_charge_desc_poss cocaine/intent to del/sel
# 0.803461438168 c_charge_desc_prowling/loitering
# 0.786103837616 c_charge_desc_possession of cocaine
# 0.783340329506 c_charge_desc_felony dui (level 3)
# 0.764838759329 c_charge_desc_poss pyrrolidinovalerophenone
# 0.750748098897 c_charge_desc_deliver cannabis
# 0.748838722175 c_charge_desc_petit theft
# 0.747573463182 c_charge_desc_deliver cocaine
# 0.746547854705 vr_charge_desc_felony battery w/prior convict
# 0.734804176959 r_charge_desc_unlaw use false name/identity
# 0.698627644687 c_charge_desc_grand theft (motor vehicle)
# 0.697080695875 c_charge_desc_poss of cocaine w/i/d/s 1000ft park
# 0.694179963057 r_charge_desc_robbery / no weapon
# 0.671362857916 race_african-american
# 0.641707693268 r_charge_desc_resisting w/o violence
# ...
# 0.00483148934211 c_days_in_jail
# 0.00380390505406 c_charge_desc_use of 2 way device to fac fel
# 0.00285051108823 c_charge_desc_deposit item w/i/defraud
# 0.00212015609233 r_charge_desc_felony battery
# 0.00193975864752 r_days_in_jail
# 0.00175554666115 r_charge_desc_tamper with victim
# 0.00108541374861 c_charge_desc_threaten throw destruct device
# 0.000336426254037 vr_charge_desc_armed carjacking
# 0.000336426254037 r_charge_desc_armed carjacking
# 0.0 vr_charge_desc_manslaughter with weapon
# 0.0 vr_charge_desc_kidnapping (facilitate felony)
# 0.0 vr_charge_desc_conspiracy robbery firearm
# 0.0 vr_charge_desc_attempted arson second degree
# 0.0 vr_charge_desc_attempt felony murder
# 0.0 vr_charge_desc_att robbery sudd snatch no weap
# 0.0 vr_charge_desc_assault on law enforce officer
# 0.0 r_charge_desc_violation of injunction order/stalking/cyberstalking
# 0.0 r_charge_desc_use scanning device to defraud
# 0.0 r_charge_desc_use lost or stolen credit card
# 0.0 r_charge_desc_transport prostitution
# 0.0 r_charge_desc_trafficking 4-14 grams heroin
# 0.0 r_charge_desc_s/m/d/p/w/int 1000 sch/child c
# 0.0 r_charge_desc_grand theft dwell property
# 0.0 r_charge_desc_giving false report
# 0.0 r_charge_desc_dwls suspend cancel revoked
# 0.0 r_charge_desc_cash item w/intent to defraud
# 0.0 r_charge_desc_attempted robbery  no weapon
# 0.0 c_charge_desc_unl/disturb education/instui
# 0.0 c_charge_desc_traffick oxycodone     4g><14g
# 0.0 c_charge_desc_solicit prostitutionviolation
# 0.0 c_charge_desc_possession of paraphernalia
# 0.0 c_charge_desc_possess altered bills
# 0.0 c_charge_desc_offer agree secure for lewd act
# 0.0 c_charge_desc_impersonating police officer
# 0.0 c_charge_desc_false info leo during invest
# 0.0 c_charge_desc_dwi w/inj susp lic / habit off
# 0.0 c_charge_desc_deliver oxycodone
# 0.0 c_charge_desc_battery spouse or girlfriend
# 0.0 c_charge_desc_attempted aggravated battery
# 0.0 c_charge_desc_arson in the first degree
# -0.000480214825612 vr_charge_desc_child abuse
# -0.000821303171371 c_charge_desc_battery on parking enfor speci
# -0.000920131629351 r_charge_desc_aid/abet burglary assault/batt
# -0.00110417323838 c_charge_desc_principal in the first degree
# -0.00168447175154 c_charge_degree_o
# -0.00302469675813 vr_charge_desc_aid/abet burglary assault/batt
# -0.00307684248041 c_charge_desc_att burgl occp dwelling
# -0.00363185703924 r_charge_desc_tresspass struct/conveyance
# -0.00415002850227 vr_charge_degree_(f3)
# -0.00540352009164 r_charge_desc_drivg while lic suspd/revk/can
# ...
# -0.537109805475 r_charge_desc_stalking (aggravated)
# -0.541848579212 c_charge_desc_fleeing or eluding a leo
# -0.551572813311 c_charge_desc_felony driving while lic suspd
# -0.552783252354 r_charge_desc_driving while dl susp / financial resp
# -0.564351478242 r_charge_desc_burglary structure unoccup
# -0.569252440537 c_charge_desc_driving under the influence
# -0.587689387763 c_charge_desc_corrupt public servant
# -0.598805172427 r_charge_desc_crimin mischief damage $1000+
# -0.617247231632 c_charge_desc_lewd or lascivious molestation
# -0.620630413675 race_other
# -0.623470537046 c_charge_desc_drivg while lic suspd/revk/can
# -0.624572440648 c_charge_desc_failure to return hired vehicle
# -0.65510406178 c_charge_desc_criminal mischief damage <$200
# -0.676642387933 vr_charge_desc_burglary dwelling assault/batt
# -0.698330347356 c_charge_desc_dui level 0.15 or minor in veh
# -0.713701851914 c_charge_desc_child abuse
# -0.795090619867 c_charge_desc_felony battery (dom strang)
# -0.813601132668 c_charge_desc_tamper with witness/victim/ci
# -0.842755951576 r_charge_desc_expired dl more than 6 months
# -0.923276339602 c_charge_desc_cruelty toward child

# %% [markdown]
# Let's check the non-crime label ones specifically

# %%
for a, b in coeffs: print(a, b) if 'charge_desc' not in b else ...
# Out:
# 0.671362857916 race_african-american
# 0.532643550234 race_native american
# 0.517917289476 is_violent_recid
# 0.358295678854 vr_charge_degree_(f7)
# 0.355421952635 is_recid
# 0.292999683579 vr_charge_degree_(m2)
# 0.26034588717 juv_fel_count
# 0.252770759163 juv_other_count
# 0.222022233675 priors_count
# 0.212178042404 vr_charge_degree_(f6)
# 0.204834840463 r_charge_degree_f
# 0.133357706964 juv_misd_count
# 0.0813856044311 sex_female
# 0.0740144190665 c_charge_degree_f
# 0.0655252589349 race_caucasian
# 0.0641869599376 vr_charge_degree_(f1)
# 0.0322916860824 vr_charge_degree_(mo3)
# 0.00483148934211 c_days_in_jail
# 0.00193975864752 r_days_in_jail
# -0.00168447175154 c_charge_degree_o
# -0.00415002850227 vr_charge_degree_(f3)
# -0.0239280909414 vr_charge_degree_(f5)
# -0.072329947315 c_charge_degree_m
# -0.0813856044311 sex_male
# -0.0909063601894 age
# -0.0918325400547 r_charge_degree_m
# -0.113002300408 r_charge_degree_o
# -0.205276207035 vr_charge_degree_(m1)
# -0.208680434903 vr_charge_degree_(f2)
# -0.295009621143 race_hispanic
# -0.353891632267 race_asian
# -0.620630413675 race_other

# %% [markdown]
# Try linear support vector regression next

# %%
from sklearn import svm

model = svm.LinearSVR(epsilon=0.5)
scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=10, n_jobs=2)
scores
# Out:
# array([-0.61469311, -3.66407706,  0.34482374,  0.01771783, -0.46750105,
#        -0.14204074,  0.23770379,  0.37259487,  0.20467988,  0.26196131])

# %% [markdown]
# Marginally better, still pretty bad. Let's try support vector regression with an RBF. In principle it has an infinite-dimensional faeture space so that should get to something reasonable at the cost of possibly overfitting.

# %%
from sklearn import svm

model = svm.SVR(epsilon=0.5)
scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=10, n_jobs=3)
scores
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-e0c05df41b02> in <module>()
#       2
#       3 model = svm.SVR(epsilon=0.5)
# ----> 4 scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=10, n_jobs=3)
#       5 scores
#
# ~/venv/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     138                                               train, test, verbose, None,
#     139                                               fit_params)
# --> 140                       for train, test in cv_iter)
#     141     return np.array(scores)[:, 0]
#     142
#
# ~/venv/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     766                 # consumption.
#     767                 self._iterating = False
# --> 768             self.retrieve()
#     769             # Make sure that we get a last message telling us we are done
#     770             elapsed_time = time.time() - self._start_time
#
# ~/venv/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     717                     ensure_ready = self._managed_backend
#     718                     backend.abort_everything(ensure_ready=ensure_ready)
# --> 719                 raise exception
#     720
#     721     def __call__(self, iterable):
#
# ~/venv/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     680                 # check if timeout supported in backend future implementation
#     681                 if 'timeout' in getfullargspec(job.get).args:
# --> 682                     self._output.extend(job.get(timeout=self.timeout))
#     683                 else:
#     684                     self._output.extend(job.get())
#
# /usr/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /usr/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %% [markdown]
# It's... not bad(?) considering we are using $\frac{1}{3}$ of the data for testing on each round of the cross validation. The resulting $R^2$ values indicate $R \approx 0.6$ which is by no means an abysmal degree of correlation. At the same time, we would expect a significantly higher degree of success based on what the task actually **is**.
#
# Might be problem with the nature of the data, more specifically not enough data for practical learning considering the size of the (unmodified) feature space. We only have ~10x data points to the number of features.
#
# Might want to try, say, a random forest or alternatively doing some tricks with sample generation. Might also be issues regarding colinearity, but that's a bit beyond me, to be quite hones.
