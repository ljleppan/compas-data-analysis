# %% [markdown]
# Import our tools

# %%
import pandas as pd

# %% [markdown]
# Load in the relevant data, parsing the date fields to a format pandas understands on the way.

# %%
df = pd.read_csv(
    'compas-scores.csv',
    usecols=[
        'sex',
        'age',
        'age_cat',
        'race',
        'juv_fel_count', 
        'decile_score', 
        'juv_misd_count',
        'juv_other_count', 
        'priors_count', 
        'days_b_screening_arrest',
        'c_jail_in', 
        'c_jail_out',
        'c_offense_date',
        'c_arrest_date', 
        'c_days_from_compas', 
        'c_charge_degree',
        'c_charge_desc', 
        'is_recid', 
        'num_r_cases', 
        'r_charge_degree', 
        'r_days_from_arrest', 
        'r_offense_date',
        'r_charge_desc', 
        'r_jail_in', 
        'r_jail_out', 
        'is_violent_recid',
        'num_vr_cases', 
        'vr_charge_degree', 
        'vr_offense_date',
        'vr_charge_desc', 
        #'v_decile_score',
        #'v_score_text', 
        'v_screening_date', 
        #'score_text', 
    ],
    parse_dates=[
        'c_jail_in', 
        'c_jail_out', 
        'c_offense_date', 
        'c_arrest_date', 
        'r_offense_date', 
        'r_jail_in', 
        'r_jail_out', 
        'vr_offense_date',
        'v_screening_date'
    ]
)

# %% [markdown]
# Transform all string data to lowercase and remove extra whitespace

# %%
df = df.applymap(lambda s : s.lower().strip() if type(s) == str else s)

# %% [markdown]
# Transform all string columns to groups of binary columns

# %%
df = pd.get_dummies(df)

# %% [markdown]
# Check if we have any more object columns (should be none)

# %%
df.dtypes.value_counts()
# Out:
# uint8             982
# datetime64[ns]      9
# int64               8
# float64             5
# dtype: int64

# %% [markdown]
# Calculate jail stay lengths

# %%
df['c_days_in_jail'] = (df['c_jail_out'] - df['c_jail_in']).dt.days.fillna(0).astype(int)
df['r_days_in_jail'] = (df['r_jail_out'] - df['r_jail_in']).dt.days.fillna(0).astype(int)

# %% [markdown]
# Drop date columns

# %%
df.drop([
        'c_jail_in', 
        'c_jail_out', 
        'c_offense_date', 
        'c_arrest_date', 
        'r_offense_date', 
        'r_jail_in', 
        'r_jail_out', 
        'vr_offense_date',
        'v_screening_date'
    ],
    axis='columns',
    inplace=True
)

# %% [markdown]
# Check dtypes again, should be no dates remaining

# %%
df.dtypes.value_counts()
# Out:
# uint8      982
# int64       10
# float64      5
# dtype: int64

# %% [markdown]
# Still a few floats, see what that is all about

# %%
df.select_dtypes(include=['float64'])
# Out:
#        days_b_screening_arrest  c_days_from_compas  num_r_cases  \
# 0                         -1.0                 1.0          NaN
# 1                          NaN                 NaN          NaN
# 2                         -1.0                 1.0          NaN
# 3                         -1.0                 1.0          NaN
# 4                          NaN                 1.0          NaN
# 5                          NaN                76.0          NaN
# 6                          0.0                 0.0          NaN
# 7                         -1.0                 1.0          NaN
# 8                         -1.0                 1.0          NaN
# 9                         -1.0                 1.0          NaN
# 10                        -1.0                 1.0          NaN
# 11                        -1.0                 1.0          NaN
# 12                       428.0               308.0          NaN
# 13                        -1.0                 1.0          NaN
# 14                         0.0                 0.0          NaN
# 15                         0.0                 0.0          NaN
# 16                         0.0                 0.0          NaN
# 17                        -1.0                 1.0          NaN
# 18                       -20.0               490.0          NaN
# 19                        22.0                71.0          NaN
# 20                         0.0                 0.0          NaN
# 21                        -1.0                 1.0          NaN
# 22                        -1.0                 1.0          NaN
# 23                        -1.0                 1.0          NaN
# 24                        -1.0                 1.0          NaN
# 25                        -1.0                 1.0          NaN
# 26                         0.0                 0.0          NaN
# 27                        -2.0                 2.0          NaN
# 28                         0.0                 0.0          NaN
# 29                         0.0                 1.0          NaN
# ...                        ...                 ...          ...
# 11727                      0.0                 0.0          NaN
# 11728                     -1.0                 1.0          NaN
# 11729                    -69.0                69.0          NaN
# 11730                     -1.0                 1.0          NaN
# 11731                     -1.0                 1.0          NaN
# 11732                     -1.0                 1.0          NaN
# 11733                     -1.0                 1.0          NaN
# 11734                     -1.0                 1.0          NaN
# 11735                     -1.0                 1.0          NaN
# 11736                     -1.0                 1.0          NaN
# 11737                     -1.0                 1.0          NaN
# 11738                     -1.0                 1.0          NaN
# 11739                     -2.0                 3.0          NaN
# 11740                      0.0                 1.0          NaN
# 11741                     -1.0                 1.0          NaN
# 11742                     -1.0                 1.0          NaN
# 11743                      0.0                 0.0          NaN
# 11744                    -44.0                45.0          NaN
# 11745                      0.0                 0.0          NaN
# 11746                      0.0                 1.0          NaN
# 11747                      0.0                 0.0          NaN
# 11748                     -1.0                 1.0          NaN
# 11749                     -1.0                 1.0          NaN
# 11750                     -1.0                 1.0          NaN
# 11751                     -2.0                 2.0          NaN
# 11752                     -1.0                 1.0          NaN
# 11753                     -1.0                 1.0          NaN
# 11754                      NaN                 1.0          NaN
# 11755                   -196.0               196.0          NaN
# 11756                     -1.0                 1.0          NaN
#
#        r_days_from_arrest  num_vr_cases
# 0                     NaN           NaN
# 1                     NaN           NaN
# 2                     NaN           NaN
# 3                     0.0           NaN
# 4                     NaN           NaN
# 5                     NaN           NaN
# 6                     NaN           NaN
# 7                     0.0           NaN
# 8                     NaN           NaN
# 9                     NaN           NaN
# 10                    NaN           NaN
# 11                    NaN           NaN
# 12                    0.0           NaN
# 13                    NaN           NaN
# 14                    NaN           NaN
# 15                    NaN           NaN
# 16                    NaN           NaN
# 17                    NaN           NaN
# 18                    0.0           NaN
# 19                    0.0           NaN
# 20                    NaN           NaN
# 21                    NaN           NaN
# 22                    NaN           NaN
# 23                    1.0           NaN
# 24                    0.0           NaN
# 25                    0.0           NaN
# 26                    NaN           NaN
# 27                    NaN           NaN
# 28                    NaN           NaN
# 29                    NaN           NaN
# ...                   ...           ...
# 11727                 NaN           NaN
# 11728                 NaN           NaN
# 11729                 NaN           NaN
# 11730                 NaN           NaN
# 11731                 NaN           NaN
# 11732                 NaN           NaN
# 11733                 0.0           NaN
# 11734                 NaN           NaN
# 11735                 NaN           NaN
# 11736               149.0           NaN
# 11737                 0.0           NaN
# 11738                 NaN           NaN
# 11739                 NaN           NaN
# 11740                 NaN           NaN
# 11741                 NaN           NaN
# 11742                 NaN           NaN
# 11743                 0.0           NaN
# 11744                 NaN           NaN
# 11745                 NaN           NaN
# 11746                 NaN           NaN
# 11747                 NaN           NaN
# 11748                 NaN           NaN
# 11749                 NaN           NaN
# 11750                 NaN           NaN
# 11751                 1.0           NaN
# 11752                 NaN           NaN
# 11753                 NaN           NaN
# 11754                 NaN           NaN
# 11755                 NaN           NaN
# 11756                 NaN           NaN
#
# [11757 rows x 5 columns]

# %% [markdown]
# At least two look like only NaNs, check to be sure

# %%
print(df['num_vr_cases'].value_counts())
print(df['num_r_cases'].value_counts())
# Out:
# Series([], Name: num_vr_cases, dtype: int64)
# Series([], Name: num_r_cases, dtype: int64)

# %% [markdown]
# Yeah, NaNs only. We can drop those.

# %%
df.drop([
        'num_r_cases',
        'num_vr_cases'
    ],
    axis='columns',
    inplace=True
)

# %% [markdown]
# Replace other NaNs with column means (imputation) and check the columns again

# %%
df.fillna(df.mean(), inplace=True)
df.select_dtypes(include=['float64'])
# Out:
#        days_b_screening_arrest  c_days_from_compas  r_days_from_arrest
# 0                    -1.000000            1.000000           20.410569
# 1                    -0.878037           63.587653           20.410569
# 2                    -1.000000            1.000000           20.410569
# 3                    -1.000000            1.000000            0.000000
# 4                    -0.878037            1.000000           20.410569
# 5                    -0.878037           76.000000           20.410569
# 6                     0.000000            0.000000           20.410569
# 7                    -1.000000            1.000000            0.000000
# 8                    -1.000000            1.000000           20.410569
# 9                    -1.000000            1.000000           20.410569
# 10                   -1.000000            1.000000           20.410569
# 11                   -1.000000            1.000000           20.410569
# 12                  428.000000          308.000000            0.000000
# 13                   -1.000000            1.000000           20.410569
# 14                    0.000000            0.000000           20.410569
# 15                    0.000000            0.000000           20.410569
# 16                    0.000000            0.000000           20.410569
# 17                   -1.000000            1.000000           20.410569
# 18                  -20.000000          490.000000            0.000000
# 19                   22.000000           71.000000            0.000000
# 20                    0.000000            0.000000           20.410569
# 21                   -1.000000            1.000000           20.410569
# 22                   -1.000000            1.000000           20.410569
# 23                   -1.000000            1.000000            1.000000
# 24                   -1.000000            1.000000            0.000000
# 25                   -1.000000            1.000000            0.000000
# 26                    0.000000            0.000000           20.410569
# 27                   -2.000000            2.000000           20.410569
# 28                    0.000000            0.000000           20.410569
# 29                    0.000000            1.000000           20.410569
# ...                        ...                 ...                 ...
# 11727                 0.000000            0.000000           20.410569
# 11728                -1.000000            1.000000           20.410569
# 11729               -69.000000           69.000000           20.410569
# 11730                -1.000000            1.000000           20.410569
# 11731                -1.000000            1.000000           20.410569
# 11732                -1.000000            1.000000           20.410569
# 11733                -1.000000            1.000000            0.000000
# 11734                -1.000000            1.000000           20.410569
# 11735                -1.000000            1.000000           20.410569
# 11736                -1.000000            1.000000          149.000000
# 11737                -1.000000            1.000000            0.000000
# 11738                -1.000000            1.000000           20.410569
# 11739                -2.000000            3.000000           20.410569
# 11740                 0.000000            1.000000           20.410569
# 11741                -1.000000            1.000000           20.410569
# 11742                -1.000000            1.000000           20.410569
# 11743                 0.000000            0.000000            0.000000
# 11744               -44.000000           45.000000           20.410569
# 11745                 0.000000            0.000000           20.410569
# 11746                 0.000000            1.000000           20.410569
# 11747                 0.000000            0.000000           20.410569
# 11748                -1.000000            1.000000           20.410569
# 11749                -1.000000            1.000000           20.410569
# 11750                -1.000000            1.000000           20.410569
# 11751                -2.000000            2.000000            1.000000
# 11752                -1.000000            1.000000           20.410569
# 11753                -1.000000            1.000000           20.410569
# 11754                -0.878037            1.000000           20.410569
# 11755              -196.000000          196.000000           20.410569
# 11756                -1.000000            1.000000           20.410569
#
# [11757 rows x 3 columns]

# %% [markdown]
# Should be no more NaNs to go, so we can continue to learning.

# %% [markdown]
# Split to target and explanatory variables

# %%
predicted_variable = 'decile_score'
X = df.loc[:, df.columns != predicted_variable]
y = df.loc[:, df.columns == predicted_variable]
print(X.shape, y.shape)
# Out:
# (11757, 994) (11757, 1)

# %% [markdown]
# Split to train and test sets

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# Train a linear classifier and check the $R^2$ score. Score of 1 is best possible, values can range to $-\inf$. We do a 10-fold cross validation to get a better sense of the model fit.

# %%
from sklearn import linear_model

model = linear_model.LinearRegression(normalize=True)
scores = model_selection.cross_val_score(model, X, y, cv=5)
scores
# Out:
# array([ -6.83044025e+27,  -1.19054010e+28,  -5.69988528e+27,
#         -9.25803996e+27,  -8.88523580e+27])

# %% [markdown]
# Absolute rubbish, try linear support vector regression instead

# %%
from sklearn import svm

model = svm.LinearSVR(epsilon=0.5)
scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=5, n_jobs=2)
scores
# Out:
# array([  3.01579093e-01,   2.00690892e-02,  -4.35889931e-01,
#          1.29654965e-01,  -5.52683440e+01])

# %% [markdown]
# Marginally better, still pretty bad. Let's try support vector regression with an RBF. In principle it has an infinite-dimensional faeture space so that should get to something reasonable at the cost of possibly overfitting.

# %%
from sklearn import svm

model = svm.SVR(epsilon=0.5)
scores = model_selection.cross_val_score(model, X, y.values.ravel(), cv=3, n_jobs=3)
scores

# %% [markdown]
# It's... not bad(?) considering we are using $\frac{1}{3}$ of the data for testing on each round of the cross validation. The resulting $R^2$ values indicate $R \approx 0.6$ which is by no means an abysmal degree of correlation. At the same time, we would expect a significantly higher degree of success based on what the task actually **is**.
#
# Might be problem with the nature of the data, more specifically not enough data for practical learning considering the size of the (unmodified) feature space. We only have ~10x data points to the number of features.
#
# Might want to try, say, a random forest or alternatively doing some tricks with sample generation. Might also be issues regarding colinearity, but that's a bit beyond me, to be quite hones.
